# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    - -------------------------------------- 1.6/38.8 MB 9.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 5.8/38.8 MB 16.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 10.7/38.8 MB 19.2 MB/s eta 0:00:02
#    --------------- ------------------------ 14.9/38.8 MB 19.2 MB/s eta 0:00:02
#    --------------------- ------------------ 21.0/38.8 MB 21.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.5/38.8 MB 23.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.8 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 25.7 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 23.7 MB/s eta 0:00:00
# ...

# %%
import os
import cv2

# Ruta al dataset
folder_path = r'C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua'

for root, dirs, files in os.walk(folder_path):
    for file in files:
        file_path = os.pas
        sth.join(root, file)
        
        # Leer la imagen
        img = cv2.imread(file_path)
        if img is not None:
            # Mostrar el nombre de la imagen en consola
            print(f"Archivo: {file}")
            print(f"Ubicación: {file_path}")
            
            # Pedir confirmación al usuario
            decision = input(f"¿Eliminar esta imagen ({file})? (s/n): ").strip().lower()
            if decision == 's':
                os.remove(file_path)
                print(f"Eliminada: {file_path}")
            else:
                print(f"Conservada: {file_path}")
# Out:
# Archivo: img_0_1071.jpg
# Ubicación: C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua\img_0_1071.jpg
# Eliminada: C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua\img_0_1071.jpg
# Archivo: img_0_1074.jpg
# Ubicación: C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua\img_0_1074.jpg
# Eliminada: C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua\img_0_1074.jpg
# Archivo: img_0_1082.jpg
# Ubicación: C:\Users\csolis\OneDrive - Nutreco Nederland B.V\Documents\DOCUMENTOS PERSONALES\Estudio\04_Machine_Learning\Laboratorios\Data\archive (6)\test\chihuahua\img_0_1082.jpg
# ...
